# %%
#07-02-2025

# %%
def gender_features(word):
    return {'last letter':word[-1]}

# %%
gender_features('Kirti')
# Out:
# {'last letter': 'i'}

# %%
from nltk.corpus import names

# %%
names.words()
# Out:
# ['Abagael',
#  'Abagail',
#  'Abbe',
#  'Abbey',
#  'Abbi',
#  'Abbie',
#  'Abby',
#  'Abigael',
#  'Abigail',
#  'Abigale',
#  'Abra',
#  'Acacia',
#  'Ada',
#  'Adah',
#  'Adaline',
#  'Adara',
#  'Addie',
#  'Addis',
#  'Adel',
#  'Adela',
#  'Adelaide',
#  'Adele',
#  'Adelice',
#  'Adelina',
#  'Adelind',
#  'Adeline',
#  'Adella',
#  'Adelle',
#  'Adena',
#  'Adey',
#  'Adi',
#  'Adiana',
#  'Adina',
#  'Adora',
#  'Adore',
#  'Adoree',
#  'Adorne',
#  'Adrea',
#  'Adria',
#  'Adriaens',
#  'Adrian',
#  'Adriana',
#  'Adriane',
#  'Adrianna',
#  'Adrianne',
#  'Adrien',
#  'Adriena',
#  'Adrienne',
#  'Aeriel',
#  'Aeriela',
#  'Aeriell',
#  'Ag',
#  'Agace',
#  'Agata',
#  'Agatha',
#  'Agathe',
#  'Aggi',
#  'Aggie',
#  'Aggy',
#  'Agna',
#  'Agnella',
#  'Agnes',
#  'Agnese',
#  'Agnesse',
#  'Agneta',
#  'Agnola',
#  'Agretha',
#  'Aida',
#  'Aidan',
#  'Aigneis',
#  'Aila',
#  'Aile',
#  'Ailee',
#  'Aileen',
#  'Ailene',
#  'Ailey',
#  'Aili',
#  'Ailina',
#  'Ailyn',
# ...

# %%
print(len(names.words()))
# Out:
# 7944

# %%
labeled_names=([(name,'male') for name in names.words('male.txt')]+[(name,'female') for name in names.words('female.txt')])

# %%
import random
random.shuffle(labeled_names)

# %%
featuresets=[(gender_features(n),gender) for (n,gender) in labeled_names]

# %%
train_set,test_set=featuresets[:5000],featuresets[:-2000]

# %%
import nltk
classifier=nltk.NaiveBayesClassifier.train(train_set)

# %%
classifier.classify(gender_features('Srilekha'))
# Out:
# 'female'

# %%
print(nltk.classify.accuracy(classifier,test_set))
# Out:
# 0.7674966352624495

# %%
import nltk
f=open('tweets1.txt','r')

# %%
text=f.read()
text1=text.split() # same as word tokenizer splits words based on white spaces
text2=nltk.Text(text1) #converting into text

# %%
text2.concordance("not") # will get 10 words before and after in mentioned word
# Out:
# Displaying 25 of 30 matches:
# her sites lol i work at dell and i do not know how much more microsoft i can ta
# s in hair, copters o'erhead. Here and not here. Talking about 24 in the cars, w
# r my head all the time Atleast you're not checking your mail while driving! Sta
# tart again. just a web interface does not work for me and neither does that oth
# ving fun with work:-) Sudden sunshine not improving mood. Need word for dry app
# hey're hardly meathead! But how can I not love Super Massive Black Hole?! ;) At
# atrixx.fi lookin' at utube secondlife not worth bothering with today justin.tv
# g to sleep because I am dog tired but not able to sleep (because I am dog tired
# ain to krk. yaaaaaaay new glasses! im not blind anymore! :D Chillen in west Spe
# hat some so called friends are really not calming down : ] After my first campi
# er by fring on nokia again, suprising not to happy. mmmm cheerios.. Thinking it
# ...

# %%
from urllib import request

# %%
url="https://www.gutenberg.org/files/2554/2554-0.txt"

# %%
response=request.urlopen(url)

# %%
raw=response.read().decode('utf8')

# %%
type(raw)
# Out:
# str

# %%
len(raw)
# Out:
# 1135214

# %%
raw[:75]
# Out:
# '*** START OF THE PROJECT GUTENBERG EBOOK 2554 ***\n\n\n\n\nCRIME AND PUNISHMENT\n'

# %%
from nltk.tokenize import word_tokenize
tokens=word_tokenize(raw)

# %%
type(tokens)
# Out:
# list

# %%
len(tokens)
# Out:
# 253688
